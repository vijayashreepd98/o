# %%
import re
count=0
pattern=re.compile('ab')
matcher=pattern.finditer("abaababa")
for match in matcher:
    
    count+=1
    print(match.start,".. ",match.end(),"...",match.group())
print("the number of occurence :",count)
# Out:
# <built-in method start of re.Match object at 0x0000021E0EC72D98> ..  2 ... ab
# <built-in method start of re.Match object at 0x0000021E0EC72D30> ..  5 ... ab
# <built-in method start of re.Match object at 0x0000021E0EC72D98> ..  7 ... ab
# the number of occurence : 3

# %%
import re
matcher=re.finditer("[abc]","a7b@k9z")
for match in matcher:
    print(match.start(),"...",match.group())
# Out:
# 0 ... a
# 2 ... b

# %%
matcher=re.finditer("[^abc]","a7b@k9z")
for match in matcher:
    print(match.start(),"...",match.group())
# Out:
# 1 ... 7
# 3 ... @
# 4 ... k
# 5 ... 9
# 6 ... z

# %%
matcher=re.finditer("[a-z]","a7b@k9z")
for match in matcher:
    print(match.start(),"...",match.group())
# Out:
# 0 ... a
# 2 ... b
# 4 ... k
# 6 ... z

# %%
import re
matcher=re.finditer("[abc]","a7b@k9z")
for match in matcher:
    print(match.start(),"...",match.group())
# Out:
# 0 ... a
# 2 ... b

# %%
import re
matcher=re.finditer("[0-9]","a7b@k9z")
for match in matcher:
    print(match.start(),"...",match.group())
# Out:
# 1 ... 7
# 5 ... 9

# %%
import re
matcher=re.finditer("[a-z0-9A-Z]","a7Ab@k9Bz")
for match in matcher:
    print(match.start(),"...",match.group())
# Out:
# 0 ... a
# 1 ... 7
# 2 ... A
# 3 ... b
# 5 ... k
# 6 ... 9
# 7 ... B
# 8 ... z

# %%
import re
matcher=re.finditer("[\s]","a7 b@k9z")
for match in matcher:
    print(match.start(),"...",match.group())
# Out:
# 2 ...

# %%
import re
matcher=re.finditer("[\D]","a7b@k9z")
for match in matcher:
    print(match.start(),"...",match.group())
# Out:
# 0 ... a
# 2 ... b
# 3 ... @
# 4 ... k
# 6 ... z

# %%
import re
matcher=re.finditer("[\w]","a7b@k9z")
for match in matcher:
    print(match.start(),"...",match.group())
# Out:
# 0 ... a
# 1 ... 7
# 2 ... b
# 4 ... k
# 5 ... 9
# 6 ... z

# %%
import re
matcher=re.finditer("[\W]","a7b@k9z")
for match in matcher:
    print(match.start(),"...",match.group())
# Out:
# 3 ... @

# %%
import re
matcher=re.finditer("a+","abaabaab")
for match in matcher:
    print(match.start(),"...",match.group())
# Out:
# 0 ... a
# 2 ... aa
# 5 ... aa

# %%
import re
matcher=re.finditer("a?","abaabaab")
for match in matcher:
    print(match.start(),"...",match.group())
# Out:
# 0 ... a
# 1 ...
# 2 ... a
# 3 ... a
# 4 ...
# 5 ... a
# 6 ... a
# 7 ...
# 8 ...

# %%
import re
matcher=re.finditer("a{3}","abaabaab")
for match in matcher:
    print(match.start(),"...",match.group())

# %%
import re
matcher=re.finditer("[a{3,4}]","abaabaab")
for match in matcher:
    print(match.start(),"...",match.group())
# Out:
# 0 ... a
# 2 ... a
# 3 ... a
# 5 ... a
# 6 ... a

# %%
s="Learning Python is very Easy"
res=re.search("^Learn",s)
if res!=None:
    print("Target string starts with learn")
else:
    print("Target string not starts with learn")
# Out:
# Target string starts with learn

# %%
s="Learning Python is very Easy"
res=re.search("Easy$",s)
if res!=None:
    print("Target string starts with Easy")
else:
    print("Target string not starts with Easy")
# Out:
# Target string starts with Easy

# %%
s="Learning Python is very easy"
res=re.search("Easy$",s,re.IGNORECASE)
if res!=None:
    print("Target string starts with Easy")
else:
    print("Target string not starts with Easy")
# Out:
# Target string starts with Easy

# %%
s=int(input("enter number"))
res=re.search("[0-9]*",s)
if res!=None:
    print("is a proper mobile no")
else:
    print("is not a valid number")
# Out:
# enter number7894934557
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-5b43bc67f36e> in <module>
#       1 s=int(input("enter number"))
# ----> 2 res=re.search("[7-9][0-9]*",s)
#       3 if res!=None:
#       4     print("is a proper mobile no")
#       5 else:
#
# E:\anaconda3\lib\re.py in search(pattern, string, flags)
#     181     """Scan through string looking for a match to the pattern, returning
#     182     a Match object, or None if no match was found."""
# --> 183     return _compile(pattern, flags).search(string)
#     184
#     185 def sub(pattern, repl, string, count=0, flags=0):
#
# TypeError: expected string or bytes-like object

# %%
import re
inp=input("enter mobile number")
res=re.search("^[6789][0-9]{9}",inp)
if res!=None:
    print("correct")
else:
    print("wrong")
# Out:
# enter mobile number7893898948984985
# correct

# %%
import re
inp=input("enter mobile number")
res=re.search("^[6789][0-9]{9}",inp)
if res!=None:
    print("correct")
else:
    print("wrong")
# Out:
# enter mobile number78928827364
# correct

# %%
s=input("enter mobile number")
#num=int(num)
res1=re.search('^[6-9]',s)
if len(s)==10 and res1!=None:
    print("Correct")
else:
    print("not correct")
# Out:
# enter monile number7834886455
# Correct

# %%
fhand=open("number.txt",'r')
f1=open("output.txt",'w')
for line in fhand:
    list=re.findall("[6-9]\d{9}",line)
    for n in list:
        f1.write(n+"\n")
print("extracted all mobile numbers")
fhand.close()
f1.close()
# Out:
# extracted all mobile numbers

# %%
f1=open("carplate.txt",'r')
f2=open('output1.txt','w')
for line in f1:
    list=re.findall("[KA][0][0-6][A-Z]{2}[0-9]{4}")
    for n in list:
        f1.write(n+"\n")
print("extracted all car plate number")
f1.close()
f2.close()
# Out:
# extracted all car plate number

# %%
import re
s=input("enter car registration number")
m=re.fullmatch("KA[0][0-6][A-Z]{2}\d{4}",s)
if m!=None:
      print("valid")
else:
       print("invalid")
# Out:
# enter car registration numberKA05DF1245
# valid

# %%
import re
s=input("enter EMAIL id")
m=re.fullmatch("\w[a-zA-Z0-9_,]*@gmail[.]com",s)
if m!=None:
      print("valid")
else:
       print("invalid")
# Out:
# enter EMAIL idvijjugmain.com
# invalid

# %%
f1=open("carplate.txt",'r')
f2=open('output1.txt','w')
for line in f1:
    list=re.findall("[KA][0][0-6][A-Z]{2}[0-9]{4}")
    for n in list:
        f1.write(n+"\n")
print("extracted all car plate number")
f1.close()
f2.close()
# Out:
# extracted all car plate number

# %%
import numpy as np
import pandas as pd
rm=pd.read_csv("titanic_test.csv")

# %%
rm
# Out:
#      PassengerId  Pclass                                               Name  \
# 0            892       3                                   Kelly, Mr. James
# 1            893       3                   Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                          Myles, Mr. Thomas Francis
# 3            895       3                                   Wirz, Mr. Albert
# 4            896       3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5            897       3                         Svensson, Mr. Johan Cervin
# 6            898       3                               Connolly, Miss. Kate
# 7            899       2                       Caldwell, Mr. Albert Francis
# 8            900       3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9            901       3                            Davies, Mr. John Samuel
# 10           902       3                                   Ilieff, Mr. Ylio
# ...

# %%
rm1=pd.read_csv("titanic_train.csv")

# %%
rm1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
rm2=pd.read_csv("advertising.csv")

# %%
rm2
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                       68.95   35     61833.90                256.09
# 1                       80.23   31     68441.85                193.77
# 2                       69.47   26     59785.94                236.50
# 3                       74.15   29     54806.18                245.89
# 4                       68.37   35     73889.99                225.58
# 5                       59.99   23     59761.56                226.74
# 6                       88.91   33     53852.85                208.36
# 7                       66.00   48     24593.33                131.76
# 8                       74.53   30     68862.00                221.51
# 9                       69.88   20     55642.32                183.82
# 10                      47.64   49     45632.51                122.02
# 11                      83.07   37     62491.01                230.87
# ...
